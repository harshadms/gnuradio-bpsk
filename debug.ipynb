# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
hdr = "/tmp/tx_packet_hdr"
pld = "/tmp/tx_packet_pld"

h = np.fromfile(hdr, dtype=np.complex64)
p = np.fromfile(pld, dtype=np.complex64)

plt.figure(figsize=(20,4))

plt.plot(h)
print(len(p))
plt.plot(np.linspace(383,383+360,360), p)
# Out:
# 360
# /usr/lib/python3/dist-packages/matplotlib/cbook/__init__.py:1298: ComplexWarning: Casting complex values to real discards the imaginary part
#   return np.asarray(x, float)
# /usr/lib/python3/dist-packages/matplotlib/cbook/__init__.py:1298: ComplexWarning: Casting complex values to real discards the imaginary part
#   return np.asarray(x, float)

# %%
hdr = "/tmp/tx_packet_hdr_1"
pld = "/tmp/tx_packet_pld_1"

h = np.fromfile(hdr, dtype=np.complex64)
p = np.fromfile(pld, dtype=np.complex64)

plt.figure(figsize=(20,4))

plt.plot(h)
print(len(p))
plt.plot(np.linspace(383,383+360,360), p)
# Out:
# 360
# /usr/lib/python3/dist-packages/matplotlib/cbook/__init__.py:1298: ComplexWarning: Casting complex values to real discards the imaginary part
#   return np.asarray(x, float)
# /usr/lib/python3/dist-packages/matplotlib/cbook/__init__.py:1298: ComplexWarning: Casting complex values to real discards the imaginary part
#   return np.asarray(x, float)

# %%
hdr = "/tmp/tx_packet"

pkt = np.fromfile(hdr, dtype=np.complex64)

plt.figure(figsize=(20,4))

plt.plot(pkt)
# Out:
# /usr/lib/python3/dist-packages/matplotlib/cbook/__init__.py:1298: ComplexWarning: Casting complex values to real discards the imaginary part
#   return np.asarray(x, float)

# %%
import pandas as pd

columns = ['id','tx_time','rx_samp','index','dt','frac_samp']
csv_file = "./rx_tx_timestamps.csv"
df = pd.read_csv(csv_file) #, names=columns)
df.to_pickle("./rx_data_2.pkl")
df.dt.var()
# Out:
# 3.1554368001951424e-06

# %%
with open("/tmp/payload_bytes","rb") as f:
    d = f.read()

print(d)
# Out:
# b'Testing-123456789#\x83-Q'
