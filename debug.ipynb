# %%
import numpy as np
import matplotlib.pyplot as plt

fname = "/tmp/packet"

# %%
d = np.fromfile(fname)

print (len(d))

plt.figure(figsize=(20,4))
plt.plot(d)
# Out:
# 132672

# %%
import pandas as pd

columns = ['id','tx_time','rx_samp','index','dt','frac_samp']
csv_file = "./rx_tx_timestamps.csv"
df = pd.read_csv(csv_file, names=columns)
df.to_pickle("./rx_data_1.pkl")

# %%
# Out:
# 1.0459294506619718e-06
